# %%
import pandas as pd

# %%
sup_df = pd.read_excel("/home/oleksandra/Downloads/SUP 6.xlsx")
nac_df = pd.read_excel("/home/oleksandra/Downloads/NAC 6.xlsx")

# %%
sup_preview = sup_df.head(10).to_string(index=False)
print(sup_preview)
# Out:
#              0.COM
#           0000.COM
#         000000.COM
#            007.COM
#       007GMAIL.COM
#        00WMCRJ.BPT
# 01.LANDLPROMOS.BIZ
#          01760.COM
#     01CREATIVE.NET
#          01QNC.HEI
#              02.PL

# %%
nac_preview = nac_df.head(10).to_string(index=False)
print(nac_preview)
# Out:
#                    Account name             Domain name
#                             NaN                     NaN
#                             NaN                     NaN
# 101 Building Supply & Design SE 101buildingsupplync.com
#                             NaN                     NaN
#                            1045      1045realestate.com
#                            10up                10up.com
#               11th Hour Service     11thhourservice.com
#                       12 Mavens            12mavens.com
#     TwelveStone Health Partners       12stonehealth.com
#                         150BOND             150bond.com
